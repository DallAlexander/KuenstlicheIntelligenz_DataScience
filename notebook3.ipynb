# %%
# 1. Fuzzifizierung: Mitgliedsfunktionen definieren
# Fuzzy-Sets für Eingangsgröße "Temperatur"
def niedrig(x, a, b):
    if x < a:
        return 1.0
    elif a <= x <= b:
        return (b - x) / (b - a)
    else:
        return 0.0

def mittel(x):

def hoch(x):


# Fuzzy-Sets für Eingangsgröße ""

# 2. Regelbasis

# 3. Defuzzifizierung

# 4. Beispielanwendung
