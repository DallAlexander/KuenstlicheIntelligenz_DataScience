# %%
import PIL.Image
import PyPDF2 as pypdf

# %% [markdown]
# # Aufgabe 3: Unstrukturierte Daten

# %% [markdown]
# ### Textdatei einlesen

# %%
file_path = 'data/unstrukturiert/textdatei.txt'

with open(file_path, 'r', encoding='utf-8') as textfile:
    print(textfile.read())
# Out:
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Cupiditat iure exercitation sit sunt commodi eum zzril nonumy takimata dolores eum placerat sunt nibh sunt mazim rebum molestie vulputate ullamco elitr esse reprehenderit nonumy adipisici doming eos. Mazim consectetuer tation proident. Praesent lorem dolore.

# %% [markdown]
# ### Bild einlesen und anzeigen

# %%
file_path = 'data/unstrukturiert/bild.jpeg'

image = PIL.Image.open(file_path)
image.info
# Out:
# {'jfif': 257, 'jfif_version': (1, 1), 'jfif_unit': 0, 'jfif_density': (1, 1)}

# %% [markdown]
# ### PDF einlesen

# %%
file_path = 'data/unstrukturiert/pdfdatei.pdf'

reader = pypdf.PdfReader(file_path)
print(len(reader.pages))
# Out:
# 3
